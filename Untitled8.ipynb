# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0.5,2)
n = -0.7268
f1 = 35.156*t**(n)
f2 = 35.156*t**(3)

fig,ax = plt.subplots(figsize=(3,3))
ax.semilogy(t,f1)
#ax.loglog(t,f2)
ax.grid()
