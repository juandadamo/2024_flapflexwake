# %%
# %matplotlib widget
from ipywidgets import interact
import ipywidgets as widgets
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os,glob, socket
import tifffile as tif
import sympy as sp
import pickle
import time
ck = plt.rcParams['axes.prop_cycle'].by_key()['color']
mk = ['s','o','>','D','*','v','^']

# %%
def veloc_tunel(V):
    tunel_v = pd.read_csv('tunel_viento.csv',header=None)
    deltaV, U = tunel_v.to_numpy().T
    p1 = np.polyfit(deltaV,U,1)
    UdeltaV = np.poly1d(p1)
    return UdeltaV(V)
    
class camfast:
    def __init__(self,name):
        self.dir = name
        datafile = name.split('_')
        D = 50e-2
        self.th = float(datafile[1].replace('t',''))*1e-6
        self.L = float(datafile[2].replace('L',''))/100*D
        self.veloc = 1
        self.DeltaV = 1
        self.drag_i = 1
        g = 9.8
        if self.th == 75e-6:
            self.rho = 1300
            self.y1 = 37.3e-3
        elif self.th == 50e-6:
            self.rho = 1900
            self.y1 = 50.2e-3
        else:
            self.th = 10000
            self.rho = 1900
            self.y1 = 0.01


        self.B =  ((self.y1*1.103)**3)*self.rho*self.th*g # rigidez a la flexion por unidad de longitud
        self.I = (self.th)**3/12  #momento de inercia por unidad de longitud
        self.E = self.B / self.I

        self.coords = 0
        self.IM_vec0 = 0
        self.IM_vec1 = 0
        self.IM_mean = 0
        self.IM_std = 0
        self.FFT_VEC0 = 0
        self.FFT_VEC1 = 0
        self.FFT_fps = 250
        self.FFT_freqs = 0

    def flex_rig(self):
        g = 9.8
        if self.th == 75e-6:
            self.rho = 1300
            self.y1 = 37.3e-3
        elif self.th == 50e-6:
            self.rho = 1900
            self.y1 = 50.2e-3
        else:
            self.th = 10000
            self.rho = 1900
            self.y1 = 0.01
        self.B =  ((self.y1*1.103)**3)*self.rho*self.th*g # rigidez a la flexion por unidad de longitud
        self.I = (self.th)**3/12  #momento de inercia por unidad de longitud
        self.E = self.B / self.I

# %%
lista_files = np.sort(glob.glob('fastcam_objs/*.pickle'))
fastcam_objs = []
fastcam_objs_0 = []
D = 50e-3
for i, filei in enumerate(lista_files):
    file_aux = open(filei, 'rb')
    A = pickle.load(file_aux)
    A.th = np.round(float(filei.split('_t')[-1][:3])*1e-6,6)
    A.L = np.round(float(filei.split('_L')[-1][:3])/100*D,4)
    A.deltaV = float(filei.split('_v')[-1].split('_')[0])
    A.veloc = veloc_tunel(A.deltaV )
    A.drag_i = []
    A.label_drag_i = []
    A.file_caso = filei
    nombre_csv_drag = f'medidas/back/Dshape_e{int(np.round(A.th*1e6,2)):02d}_L{int(np.round(A.L/D*100,3)):03d}_deltaV{int(A.deltaV):01d}*'
    nombre_csv_drag_0 = f'medidas/back/Dshape_e{int(np.round(A.th*1e6,2)):02d}_L{int(np.round(A.L/D*100,3)):03d}_deltaV{int(0):01d}*'
    lista_files_drag = glob.glob(nombre_csv_drag)
    lista_files_drag_0 = glob.glob(nombre_csv_drag_0)
    time_drag_0 = np.array([os.path.getmtime(filei) for filei in  lista_files_drag_0])
    for j,file_drag_j in enumerate(lista_files_drag):
        index_file_drag_0 = np.argmin(np.abs(os.path.getmtime(file_drag_j) - time_drag_0))
        aux = pd.read_csv(file_drag_j,header=None)
        aux0 = pd.read_csv(lista_files_drag_0[index_file_drag_0],header=None)
        A.drag_i.append(aux.iloc[:,3].to_numpy()-aux0.iloc[:,3].mean())
        A.label_drag_i.append((file_drag_j,lista_files_drag_0[index_file_drag_0]))
        #if j==1:
        #    raise ValueError()
        #print(index_file_drag_0)
    A.drag_i_mean = []        
    for drag_i in A.drag_i:
        A.drag_i_mean.append(drag_i.mean())
    A.flex_rig()
    nombre_csv_cam = f'output_fastcam/t{int(np.round(A.th*1e6,2)):03d}L{int(np.round(A.L/D*100,3)):03d}v{int(A.deltaV):01d}*'
    lista_files_cam = glob.glob(nombre_csv_cam)
    A.coords_cam = []
    A.deltay = []
    A.files_cam = []
    for j,file_cam_j in enumerate(lista_files_cam):
        aux2 = pd.read_csv(file_cam_j)#,header=None)
        A.coords_cam.append(aux2.to_numpy())
        A.files_cam.append(file_cam_j)
    #for coords in A.coords_cam:    
    #    deltayi1 = -coords[1,2] + coords[1,1]
    #    deltayi2 = coords[2,2] - coords[3,2]
    #    A.deltay.append((deltayi1,deltayi2))
    #A.deltaymax = np.max(A.deltay)


    if A.deltaV != 0:
        fastcam_objs.append(A)
    else:
        fastcam_objs_0.append(A)
    #fastcam_objs.append(A)
    file_aux.close()
        
    #if i==1:raise ValueError()

# %%
A.coords_cam
# Out:
# [array([['x0', 356.017316017316, 702.0606060606061],
#         ['x1', 757.7489177489177, 733.922077922078],
#         ['x2', 343.5497835497835, 298.1125541125541],
#         ['x3', 772.987012987013, 295.3419913419914]], dtype=object),
#  array([['x0', 339.3939393939394, 724.2251082251082],
#         ['x1', 752.2077922077922, 735.3073593073593],
#         ['x2', 325.5411255411255, 300.88311688311694],
#         ['x3', 756.3636363636364, 299.4978354978356]], dtype=object)]

# %%
A = fastcam_objs[29]
fig,ax   = plt.subplots()
ax.contourf(A.IM_mean)
for i,coord in enumerate(A.coords_cam[0]):
    xi,yi = coord[1:]
    ax.plot(xi,yi,marker = 'o',markeredgecolor='r',markerfacecolor=None)
    ax.text(xi,yi,'%0d'%i,fontsize=16,color='w')
ax.set_title(A.file_caso);

A.coords_cam
# Out:
# [array([['x0', 227.18614718614717, 732.5367965367966],
#         ['x1', 761.9047619047619, 739.4632034632035],
#         ['x2', 224.4155844155844, 314.7359307359308],
#         ['x3', 766.0606060606061, 299.4978354978356]], dtype=object)]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
A = fastcam_objs[29]
fig,ax   = plt.subplots()
ax.contourf(A.IM_vec0.T)

ax.set_title(A.file_caso);

A.coords_cam
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 6
#       3 ax.contourf(A.IM_vec0.T)
#       5 ax.set_title(A.file_caso);
# ----> 6 ax.set_ylim([])
#       7 A.coords_cam
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:3875, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3810 """
#    3811 Set the y-axis view limits.
#    3812
#    (...)
#    3872 >>> set_ylim(5000, 0)
#    3873 """
#    3874 if top is None and np.iterable(bottom):
# -> 3875     bottom, top = bottom
#    3876 if ymin is not None:
#    3877     if bottom is not None:
#
# ValueError: not enough values to unpack (expected 2, got 0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
index_th50 = np.nonzero(np.array([A.th for A in fastcam_objs])==50e-6)[0]

Lengths = np.arange(0.75,1.75,0.25)
fig,ax = plt.subplots()
ij = 0
for i,index_i  in enumerate(index_th50):
    caso_cam = fastcam_objs[index_i]
    for j,Li in enumerate(Lengths[1:2]):
        if np.round(caso_cam.L/D,4)==Li:
            for k,dragi in enumerate(caso_cam.drag_i_mean):
                lin, = ax.plot(caso_cam.veloc,dragi/caso_cam.veloc**2,marker= mk[j],color=ck[j],fillstyle='none',markersize=10)
                #ax.text(caso_cam.veloc,dragi/caso_cam.veloc**2,f'$\\delta={caso_cam.deltay[0][1]:.0f}$',color=lin.get_color())
                #ax.text(caso_cam.veloc,dragi/caso_cam.veloc**2,f'$\\delta={caso_cam.deltay[0][0]:.0f}$',color='k')
                #ax.text(caso_cam.veloc+.1,dragi/caso_cam.veloc**2,f'$\\delta={caso_cam.deltay[0][1]:.0f}$',color=lin.get_color())
                ij += 1
                if ij == 20:
                    print(caso_cam.label_drag_i)
                    ax.plot(caso_cam.veloc,dragi/caso_cam.veloc**2,marker= mk[j],color='k',markersize=10)
                    
ax.grid()
# Out:
# [('medidas/back/Dshape_e50_L100_deltaV42_1', 'medidas/back/Dshape_e50_L100_deltaV0_5'), ('medidas/back/Dshape_e50_L100_deltaV42_2', 'medidas/back/Dshape_e50_L100_deltaV0_5'), ('medidas/back/Dshape_e50_L100_deltaV42_5', 'medidas/back/Dshape_e50_L100_deltaV0_5'), ('medidas/back/Dshape_e50_L100_deltaV42_3', 'medidas/back/Dshape_e50_L100_deltaV0_5'), ('medidas/back/Dshape_e50_L100_deltaV42_4', 'medidas/back/Dshape_e50_L100_deltaV0_5'), ('medidas/back/Dshape_e50_L100_deltaV42_0', 'medidas/back/Dshape_e50_L100_deltaV0_5')]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig,ax = plt.subplots()
ax.imshow(caso_cam.IM_mean,cmap='viridis_r')
for i,coord in enumerate(caso_cam.coords_cam[0]):
    xi,yi = coord[1:]
    ax.plot(xi,yi,marker = 'o',markeredgecolor='r',markerfacecolor=None)
    ax.text(xi,yi,'%0d'%i,fontsize=16,color='w')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
caso_cam.files_cam
# Out:
# ['output_fastcam/t050L150v56_0.csv', 'output_fastcam/t050L150v56_1.csv']

# %%
index_th75 = np.nonzero(np.array([A.th for A in fastcam_objs])==75e-6)[0]


Lengths = np.arange(0.75,1.75,0.25)
fig,ax = plt.subplots()
for i,index_i  in enumerate(index_th75):
    caso_cam = fastcam_objs[index_i]
    for j,Li in enumerate(Lengths):
        if np.round(caso_cam.L/D,4)==Li:
            for dragi in caso_cam.drag_i_mean:
                ax.plot(caso_cam.veloc,dragi/caso_cam.veloc**2,'o',color=ck[j])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
[obji.files_cam for obji in fastcam_objs]
# Out:
# [['output_fastcam/t050L075v40_0.csv'],
#  ['output_fastcam/t050L075v42_0.csv'],
#  ['output_fastcam/t050L075v44_0.csv'],
#  ['output_fastcam/t050L075v46_0.csv'],
#  ['output_fastcam/t050L075v48_0.csv'],
#  ['output_fastcam/t050L075v50_0.csv'],
#  ['output_fastcam/t050L075v52_0.csv'],
#  ['output_fastcam/t050L075v54_0.csv'],
#  ['output_fastcam/t050L075v56_0.csv'],
#  ['output_fastcam/t050L100v40_0.csv', 'output_fastcam/t050L100v40_1.csv'],
#  ['output_fastcam/t050L100v40_0.csv', 'output_fastcam/t050L100v40_1.csv'],
#  ['output_fastcam/t050L100v42_0.csv', 'output_fastcam/t050L100v42_1.csv'],
#  ['output_fastcam/t050L100v42_0.csv', 'output_fastcam/t050L100v42_1.csv'],
#  ['output_fastcam/t050L100v44_1.csv', 'output_fastcam/t050L100v44_0.csv'],
#  ['output_fastcam/t050L100v44_1.csv', 'output_fastcam/t050L100v44_0.csv'],
#  ['output_fastcam/t050L100v46_1.csv', 'output_fastcam/t050L100v46_0.csv'],
#  ['output_fastcam/t050L100v46_1.csv', 'output_fastcam/t050L100v46_0.csv'],
#  ['output_fastcam/t050L100v48_1.csv', 'output_fastcam/t050L100v48_0.csv'],
#  ['output_fastcam/t050L100v48_1.csv', 'output_fastcam/t050L100v48_0.csv'],
#  ['output_fastcam/t050L100v50_1.csv', 'output_fastcam/t050L100v50_0.csv'],
#  ['output_fastcam/t050L100v50_1.csv', 'output_fastcam/t050L100v50_0.csv'],
#  ['output_fastcam/t050L100v52_1.csv', 'output_fastcam/t050L100v52_0.csv'],
#  ['output_fastcam/t050L100v52_1.csv', 'output_fastcam/t050L100v52_0.csv'],
#  ['output_fastcam/t050L100v54_0.csv', 'output_fastcam/t050L100v54_1.csv'],
#  ['output_fastcam/t050L100v54_0.csv', 'output_fastcam/t050L100v54_1.csv'],
#  ['output_fastcam/t050L100v56_1.csv', 'output_fastcam/t050L100v56_0.csv'],
#  ['output_fastcam/t050L100v56_1.csv', 'output_fastcam/t050L100v56_0.csv'],
#  ['output_fastcam/t050L125v40_0.csv'],
#  ['output_fastcam/t050L125v42_0.csv'],
#  ['output_fastcam/t050L125v44_0.csv'],
#  ['output_fastcam/t050L125v46_0.csv'],
#  ['output_fastcam/t050L125v48_0.csv'],
#  ['output_fastcam/t050L125v50_0.csv'],
#  ['output_fastcam/t050L125v52_0.csv'],
#  ['output_fastcam/t050L125v54_0.csv', 'output_fastcam/t050L125v54_1.csv'],
#  ['output_fastcam/t050L125v54_0.csv', 'output_fastcam/t050L125v54_1.csv'],
#  ['output_fastcam/t050L125v56_0.csv'],
#  ['output_fastcam/t050L150v40_1.csv', 'output_fastcam/t050L150v40_0.csv'],
#  ['output_fastcam/t050L150v40_1.csv', 'output_fastcam/t050L150v40_0.csv'],
#  ['output_fastcam/t050L150v42_1.csv', 'output_fastcam/t050L150v42_0.csv'],
#  ['output_fastcam/t050L150v42_1.csv', 'output_fastcam/t050L150v42_0.csv'],
#  ['output_fastcam/t050L150v44_1.csv', 'output_fastcam/t050L150v44_0.csv'],
#  ['output_fastcam/t050L150v44_1.csv', 'output_fastcam/t050L150v44_0.csv'],
#  ['output_fastcam/t050L150v46_1.csv', 'output_fastcam/t050L150v46_0.csv'],
#  ['output_fastcam/t050L150v46_1.csv', 'output_fastcam/t050L150v46_0.csv'],
#  ['output_fastcam/t050L150v48_1.csv', 'output_fastcam/t050L150v48_0.csv'],
#  ['output_fastcam/t050L150v48_1.csv', 'output_fastcam/t050L150v48_0.csv'],
#  ['output_fastcam/t050L150v50_1.csv', 'output_fastcam/t050L150v50_0.csv'],
#  ['output_fastcam/t050L150v50_1.csv', 'output_fastcam/t050L150v50_0.csv'],
#  ['output_fastcam/t050L150v52_1.csv', 'output_fastcam/t050L150v52_0.csv'],
#  ['output_fastcam/t050L150v52_1.csv', 'output_fastcam/t050L150v52_0.csv'],
#  ['output_fastcam/t050L150v54_1.csv', 'output_fastcam/t050L150v54_0.csv'],
#  ['output_fastcam/t050L150v54_1.csv', 'output_fastcam/t050L150v54_0.csv'],
#  ['output_fastcam/t050L150v56_0.csv', 'output_fastcam/t050L150v56_1.csv'],
#  ['output_fastcam/t050L150v56_0.csv', 'output_fastcam/t050L150v56_1.csv'],
#  ['output_fastcam/t075L075v40_0.csv'],
#  ['output_fastcam/t075L075v42_0.csv'],
#  ['output_fastcam/t075L075v44_0.csv'],
#  ['output_fastcam/t075L075v46_0.csv'],
#  ['output_fastcam/t075L075v48_0.csv'],
#  ['output_fastcam/t075L075v50_0.csv'],
#  ['output_fastcam/t075L075v52_0.csv'],
#  ['output_fastcam/t075L075v54_0.csv'],
#  ['output_fastcam/t075L075v56_0.csv'],
#  ['output_fastcam/t075L100v40_0.csv'],
#  ['output_fastcam/t075L100v42_0.csv'],
#  ['output_fastcam/t075L100v44_0.csv'],
#  ['output_fastcam/t075L100v46_0.csv'],
#  ['output_fastcam/t075L100v48_0.csv'],
#  ['output_fastcam/t075L100v50_0.csv'],
#  ['output_fastcam/t075L100v52_0.csv'],
#  ['output_fastcam/t075L100v54_0.csv'],
#  ['output_fastcam/t075L100v56_0.csv'],
#  ['output_fastcam/t075L125v40_0.csv', 'output_fastcam/t075L125v40_1.csv'],
#  ['output_fastcam/t075L125v40_0.csv', 'output_fastcam/t075L125v40_1.csv'],
#  ['output_fastcam/t075L125v42_0.csv', 'output_fastcam/t075L125v42_1.csv'],
#  ['output_fastcam/t075L125v42_0.csv', 'output_fastcam/t075L125v42_1.csv'],
#  ['output_fastcam/t075L125v44_1.csv', 'output_fastcam/t075L125v44_0.csv'],
#  ['output_fastcam/t075L125v44_1.csv', 'output_fastcam/t075L125v44_0.csv'],
#  ['output_fastcam/t075L125v46_0.csv', 'output_fastcam/t075L125v46_1.csv'],
#  ['output_fastcam/t075L125v46_0.csv', 'output_fastcam/t075L125v46_1.csv'],
#  ['output_fastcam/t075L125v48_0.csv', 'output_fastcam/t075L125v48_1.csv'],
#  ['output_fastcam/t075L125v48_0.csv', 'output_fastcam/t075L125v48_1.csv'],
#  ['output_fastcam/t075L125v50_1.csv', 'output_fastcam/t075L125v50_0.csv'],
#  ['output_fastcam/t075L125v50_1.csv', 'output_fastcam/t075L125v50_0.csv'],
#  ['output_fastcam/t075L125v52_0.csv', 'output_fastcam/t075L125v52_1.csv'],
#  ['output_fastcam/t075L125v52_0.csv', 'output_fastcam/t075L125v52_1.csv'],
#  ['output_fastcam/t075L125v54_1.csv', 'output_fastcam/t075L125v54_0.csv'],
#  ['output_fastcam/t075L125v54_1.csv', 'output_fastcam/t075L125v54_0.csv'],
#  ['output_fastcam/t075L125v56_1.csv', 'output_fastcam/t075L125v56_0.csv'],
#  ['output_fastcam/t075L125v56_1.csv', 'output_fastcam/t075L125v56_0.csv'],
#  ['output_fastcam/t075L150v40_0.csv'],
#  ['output_fastcam/t075L150v42_0.csv'],
#  ['output_fastcam/t075L150v44_0.csv'],
#  ['output_fastcam/t075L150v46_0.csv'],
#  ['output_fastcam/t075L150v48_0.csv'],
#  ['output_fastcam/t075L150v50_0.csv'],
#  ['output_fastcam/t075L150v52_0.csv'],
#  ['output_fastcam/t075L150v54_0.csv'],
#  ['output_fastcam/t075L150v56_0.csv']]

# %%
A.files_cam
# Out:
# ['output_fastcam/t050L100v40_0.csv', 'output_fastcam/t050L100v40_1.csv']
